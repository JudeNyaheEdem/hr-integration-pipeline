# %%
import sys
from pathlib import Path
import logging

project_root = Path.cwd().parent
sys.path.append(str(project_root))

logging.getLogger().setLevel(logging.WARNING)

# %%
#PAYROLL
from src.config import CONFIG
from src.ingestion import ingest_all_sources
ingest= ingest_all_sources(CONFIG["input_dir"])
df=ingest["globaltech_hris"]

#df["source"].unique()
df.head(5)
# Out:
#   employee_id first_name last_name                            email  \
# 0           1    Michael      King      michael.king@globaltech.com
# 1           2      David  Phillips    david.phillips@globaltech.com
# 2           3    Kenneth  Martinez  kenneth.martinez@globaltech.com
# 3           4       Paul    Cooper       paul.cooper@globaltech.com
# 4           5    Stephen    Parker    stephen.parker@globaltech.com
#
#         department              job_title  hire_date         country  \
# 0    Manufacturing           Data Analyst 2016-09-21     Netherlands
# 1         Strategy  Systems Administrator 2022-02-06           India
# 2  Human Resources       Business Analyst 2021-06-10  United Kingdom
# 3  Human Resources   Marketing Specialist 2024-09-07       Hong Kong
# 4        Marketing        Project Manager 2023-03-09           China
#
#   employment_type manager_id           source
# 0       Full-Time      12765  globaltech_hris
# 1      Contractor       1662  globaltech_hris
# 2      Contractor       6142  globaltech_hris
# 3       Full-Time       5904  globaltech_hris
# 4       Part-Time        566  globaltech_hris

# %%
#AquiredCo
ingest= ingest_all_sources(CONFIG["input_dir"])
df=ingest["acquiredco_hris"]
df.head(5)

# %%
#PAYROLL
ingest= ingest_all_sources(CONFIG["input_dir"])
df=ingest["payroll"]

#df["source"].unique()
df.head(5)

# %%
#PAYROLL
ingest= ingest_all_sources(CONFIG["input_dir"])
df=ingest["benefits"]

#df["source"].unique()
df.head(5)
